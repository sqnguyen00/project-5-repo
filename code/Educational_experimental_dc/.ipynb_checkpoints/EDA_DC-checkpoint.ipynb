# %% [markdown]
# # EDA and modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## EDA

# %%
files =os.listdir('./temperature and precipitation/')
files
# Out:
# ['USW00003822.csv',
#  'USW00024286.csv',
#  'USW00013833.csv',
#  'USW00023066.csv',
#  'USW00093821.csv',
#  'USW00024127.csv',
#  'USW00014972.csv',
#  'USW00013984.csv',
#  'USW00003017.csv',
#  'USW00014768.csv',
#  'USW00013985.csv',
#  'USW00094815.csv',
#  'USW00093820.csv',
#  'USW00094008.csv',
#  'USW00094746.csv',
#  'USW00094949.csv',
#  'USW00094236.csv',
#  'USW00023271.csv',
#  'USW00014839.csv',
#  'USW00023065.csv',
#  'consolidated_df.csv',
#  'USW00093822.csv',
#  'USW00014742.csv',
#  'USW00003940.csv',
#  'USW00024131.csv',
#  'USC00042863.csv',
#  'USW00003820.csv',
#  'USW00024257.csv',
#  'USW00003171.csv',
#  'USW00024121.csv',
#  'USW00013996.csv',
#  'USW00014753.csv',
#  'USW00003945.csv',
#  'USW00013968.csv',
#  'USW00094973.csv',
#  'USW00094224.csv',
#  'USW00023275.csv',
#  'USW00093824.csv',
#  'USW00013942.csv',
#  'USW00014778.csv',
#  'USW00014750.csv',
#  'USW00013995.csv',
#  'USW00003953.csv',
#  'USW00003947.csv',
#  'USW00014745.csv',
#  'USW00013994.csv',
#  'USC00286055.csv',
#  'USW00013957.csv',
#  'USW00014792.csv',
#  'USW00093819.csv',
#  'USW00024232.csv',
#  'USW00024018.csv',
#  'USW00013893.csv',
#  'USW00093842.csv',
#  'USW00014939.csv',
#  'USW00024144.csv',
#  'USW00012839.csv',
#  'USW00013886.csv',
#  'USC00280734.csv',
#  'USW00024233.csv',
#  'USC00166584.csv',
#  'USW00003856.csv',
#  'USW00003103.csv',
#  'USW00024153.csv',
#  'USW00094860.csv',
#  'USW00014735.csv',
#  'USW00003937.csv',
#  'USC00356749.csv',
#  'USW00014913.csv',
#  'USW00014898.csv',
#  'USW00094040.csv',
#  'USW00024032.csv',
#  'USW00094929.csv',
#  'USW00013881.csv',
#  'USW00013895.csv',
#  'USW00023188.csv',
#  'USW00013739.csv',
#  'USW00012816.csv',
#  'USW00003927.csv',
#  'USW00024157.csv',
#  'USW00024143.csv',
#  'USW00014916.csv',
#  'USW00093058.csv',
#  'USW00024023.csv',
#  'USW00094910.csv',
#  'USW00024221.csv',
#  'USW00014860.csv',
#  'USW00024021.csv',
#  'USW00014848.csv',
#  'USW00013896.csv',
#  'USW00013882.csv',
#  'USW00023160.csv',
#  'USW00014914.csv',
#  'USW00024155.csv',
#  'USW00014733.csv',
#  'USW00012815.csv',
#  'USW00014929.csv',
#  'USW00013883.csv',
#  'USW00013897.csv',
#  'USW00093729.csv',
#  'USW00012960.csv',
#  'USW00003860.csv',
#  'USW00024213.csv',
#  'USC00380072.csv',
#  'USW00024011.csv',
#  'USW00013865.csv',
#  'USW00014918.csv',
#  'USW00013722.csv',
#  'USW00013736.csv',
#  'USW00013737.csv',
#  'USW00014925.csv',
#  'USW00023179.csv',
#  'USW00014845.csv',
#  'USW00013866.csv',
#  'USW00014847.csv',
#  'USW00013899.csv',
#  'USW00093874.csv',
#  'USW00014933.csv',
#  'USW00023185.csv',
#  'USW00094129.csv',
#  'USW00093134.csv',
#  'USW00014926.csv',
#  'USW00013873.csv',
#  'USW00094908.csv',
#  'USW00004853.csv',
#  'USW00094298.csv',
#  'USW00003872.csv',
#  'USW00014842.csv',
#  'USW00014895.csv',
#  'USW00014922.csv',
#  'USW00094850.csv',
#  'USW00014936.csv',
#  'USW00024163.csv',
#  'USW00014739.csv',
#  'USW00014711.csv',
#  'USW00012836.csv',
#  'USW00014710.csv',
#  'USW00014923.csv',
#  'USW00013889.csv',
#  'USW00014894.csv',
#  'USW00013876.csv',
#  'USW00003859.csv',
#  'USW00053920.csv',
#  'USW00024028.csv',
#  'USW00023009.csv',
#  'USW00013874.csv',
#  'USW00093721.csv',
#  'USW00094728.csv',
#  'USW00014935.csv',
#  'USW00023155.csv',
#  'USW00094847.csv',
#  'USW00013733.csv',
#  'USW00003904.csv',
#  'USW00012835.csv',
#  'USW00023183.csv',
#  'USW00094846.csv',
#  'USW00014920.csv',
#  'USW00023154.csv',
#  'USW00024149.csv',
#  'USW00014897.csv',
#  'USW00014840.csv',
#  'USW00014827.csv',
#  '.ipynb_checkpoints',
#  'USW00023047.csv',
#  'USW00094014.csv',
#  'USW00014990.csv',
#  'USW00003963.csv',
#  'USW00014991.csv',
#  'USW00013740.csv',
#  'USW00093815.csv',
#  'USW00013967.csv',
#  'USW00023044.csv',
#  'USW00023050.csv',
#  'USW00093988.csv',
#  'USW00093817.csv',
#  'USW00013971.csv',
#  'USW00094822.csv',
#  'USW00014944.csv',
#  'USW00013781.csv',
#  'USW00012844.csv',
#  'USW00013743.csv',
#  'USW00013958.csv',
#  'USW00094823.csv',
#  'USW00013964.csv',
#  'USW00013970.csv',
#  'USW00093037.csv',
#  'USW00023051.csv',
#  'USW00013838.csv',
#  'USW00012924.csv',
#  'USW00014821.csv',
#  'USW00094012.csv',
#  'USW00014941.csv',
#  'USW00024128.csv',
#  'USW00093812.csv',
#  'USW00003965.csv',
#  'USW00003145.csv',
#  'USW00012921.csv',
#  'USW00012923.csv',
#  'USW00003812.csv',
#  'USW00094950.csv',
#  'USW00014836.csv',
#  'USW00094830.csv',
#  'USW00093193.csv',
#  'USW00014942.csv',
#  'USW00013963.csv',
#  'USW00093805.csv',
#  'USW00012842.csv',
#  'USW00014764.csv',
#  'USW00013962.csv',
#  'USW00014943.csv',
#  'USW00014837.csv',
#  'USW00003813.csv']

# %%
files.remove('.ipynb_checkpoints')

# %%
files
# Out:
# ['USW00003822.csv',
#  'USW00024286.csv',
#  'USW00013833.csv',
#  'USW00023066.csv',
#  'USW00093821.csv',
#  'USW00024127.csv',
#  'USW00014972.csv',
#  'USW00013984.csv',
#  'USW00003017.csv',
#  'USW00014768.csv',
#  'USW00013985.csv',
#  'USW00094815.csv',
#  'USW00093820.csv',
#  'USW00094008.csv',
#  'USW00094746.csv',
#  'USW00094949.csv',
#  'USW00094236.csv',
#  'USW00023271.csv',
#  'USW00014839.csv',
#  'USW00023065.csv',
#  'consolidated_df.csv',
#  'USW00093822.csv',
#  'USW00014742.csv',
#  'USW00003940.csv',
#  'USW00024131.csv',
#  'USC00042863.csv',
#  'USW00003820.csv',
#  'USW00024257.csv',
#  'USW00003171.csv',
#  'USW00024121.csv',
#  'USW00013996.csv',
#  'USW00014753.csv',
#  'USW00003945.csv',
#  'USW00013968.csv',
#  'USW00094973.csv',
#  'USW00094224.csv',
#  'USW00023275.csv',
#  'USW00093824.csv',
#  'USW00013942.csv',
#  'USW00014778.csv',
#  'USW00014750.csv',
#  'USW00013995.csv',
#  'USW00003953.csv',
#  'USW00003947.csv',
#  'USW00014745.csv',
#  'USW00013994.csv',
#  'USC00286055.csv',
#  'USW00013957.csv',
#  'USW00014792.csv',
#  'USW00093819.csv',
#  'USW00024232.csv',
#  'USW00024018.csv',
#  'USW00013893.csv',
#  'USW00093842.csv',
#  'USW00014939.csv',
#  'USW00024144.csv',
#  'USW00012839.csv',
#  'USW00013886.csv',
#  'USC00280734.csv',
#  'USW00024233.csv',
#  'USC00166584.csv',
#  'USW00003856.csv',
#  'USW00003103.csv',
#  'USW00024153.csv',
#  'USW00094860.csv',
#  'USW00014735.csv',
#  'USW00003937.csv',
#  'USC00356749.csv',
#  'USW00014913.csv',
#  'USW00014898.csv',
#  'USW00094040.csv',
#  'USW00024032.csv',
#  'USW00094929.csv',
#  'USW00013881.csv',
#  'USW00013895.csv',
#  'USW00023188.csv',
#  'USW00013739.csv',
#  'USW00012816.csv',
#  'USW00003927.csv',
#  'USW00024157.csv',
#  'USW00024143.csv',
#  'USW00014916.csv',
#  'USW00093058.csv',
#  'USW00024023.csv',
#  'USW00094910.csv',
#  'USW00024221.csv',
#  'USW00014860.csv',
#  'USW00024021.csv',
#  'USW00014848.csv',
#  'USW00013896.csv',
#  'USW00013882.csv',
#  'USW00023160.csv',
#  'USW00014914.csv',
#  'USW00024155.csv',
#  'USW00014733.csv',
#  'USW00012815.csv',
#  'USW00014929.csv',
#  'USW00013883.csv',
#  'USW00013897.csv',
#  'USW00093729.csv',
#  'USW00012960.csv',
#  'USW00003860.csv',
#  'USW00024213.csv',
#  'USC00380072.csv',
#  'USW00024011.csv',
#  'USW00013865.csv',
#  'USW00014918.csv',
#  'USW00013722.csv',
#  'USW00013736.csv',
#  'USW00013737.csv',
#  'USW00014925.csv',
#  'USW00023179.csv',
#  'USW00014845.csv',
#  'USW00013866.csv',
#  'USW00014847.csv',
#  'USW00013899.csv',
#  'USW00093874.csv',
#  'USW00014933.csv',
#  'USW00023185.csv',
#  'USW00094129.csv',
#  'USW00093134.csv',
#  'USW00014926.csv',
#  'USW00013873.csv',
#  'USW00094908.csv',
#  'USW00004853.csv',
#  'USW00094298.csv',
#  'USW00003872.csv',
#  'USW00014842.csv',
#  'USW00014895.csv',
#  'USW00014922.csv',
#  'USW00094850.csv',
#  'USW00014936.csv',
#  'USW00024163.csv',
#  'USW00014739.csv',
#  'USW00014711.csv',
#  'USW00012836.csv',
#  'USW00014710.csv',
#  'USW00014923.csv',
#  'USW00013889.csv',
#  'USW00014894.csv',
#  'USW00013876.csv',
#  'USW00003859.csv',
#  'USW00053920.csv',
#  'USW00024028.csv',
#  'USW00023009.csv',
#  'USW00013874.csv',
#  'USW00093721.csv',
#  'USW00094728.csv',
#  'USW00014935.csv',
#  'USW00023155.csv',
#  'USW00094847.csv',
#  'USW00013733.csv',
#  'USW00003904.csv',
#  'USW00012835.csv',
#  'USW00023183.csv',
#  'USW00094846.csv',
#  'USW00014920.csv',
#  'USW00023154.csv',
#  'USW00024149.csv',
#  'USW00014897.csv',
#  'USW00014840.csv',
#  'USW00014827.csv',
#  'USW00023047.csv',
#  'USW00094014.csv',
#  'USW00014990.csv',
#  'USW00003963.csv',
#  'USW00014991.csv',
#  'USW00013740.csv',
#  'USW00093815.csv',
#  'USW00013967.csv',
#  'USW00023044.csv',
#  'USW00023050.csv',
#  'USW00093988.csv',
#  'USW00093817.csv',
#  'USW00013971.csv',
#  'USW00094822.csv',
#  'USW00014944.csv',
#  'USW00013781.csv',
#  'USW00012844.csv',
#  'USW00013743.csv',
#  'USW00013958.csv',
#  'USW00094823.csv',
#  'USW00013964.csv',
#  'USW00013970.csv',
#  'USW00093037.csv',
#  'USW00023051.csv',
#  'USW00013838.csv',
#  'USW00012924.csv',
#  'USW00014821.csv',
#  'USW00094012.csv',
#  'USW00014941.csv',
#  'USW00024128.csv',
#  'USW00093812.csv',
#  'USW00003965.csv',
#  'USW00003145.csv',
#  'USW00012921.csv',
#  'USW00012923.csv',
#  'USW00003812.csv',
#  'USW00094950.csv',
#  'USW00014836.csv',
#  'USW00094830.csv',
#  'USW00093193.csv',
#  'USW00014942.csv',
#  'USW00013963.csv',
#  'USW00093805.csv',
#  'USW00012842.csv',
#  'USW00014764.csv',
#  'USW00013962.csv',
#  'USW00014943.csv',
#  'USW00014837.csv',
#  'USW00003813.csv']

# %%
file_list=[]
for file in files:
    df=pd.read_csv('./temperature and precipitation/'+file, index_col=None)
    df['filename']=os.path.basename(file)
    file_list.append(df)
    
frame =pd.concat(file_list, axis=0, ignore_index=True)
#https://stackoverflow.com/questions/41857659/python-pandas-add-filename-column-csv
#https://stackoverflow.com/questions/66431680/combine-multiple-csv-files-datasets-to-make-a-joint-one

# %%
frame['filename']=frame['filename'].str.replace('.csv','')
# Out:
# <ipython-input-6-309efc490c64>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   frame['filename']=frame['filename'].str.replace('.csv','')

# %%
frame.head()
# Out:
#    Unnamed: 0        Date  tmax  tmin  prcp     filename  Unnamed: 0.1
# 0           1  1871-01-01   NaN   NaN   0.0  USW00003822           NaN
# 1           2  1871-01-02   NaN   NaN   0.0  USW00003822           NaN
# 2           3  1871-01-03   NaN   NaN   0.0  USW00003822           NaN
# 3           4  1871-01-04   NaN   NaN   0.0  USW00003822           NaN
# 4           5  1871-01-05   NaN   NaN   0.0  USW00003822           NaN

# %%
frame.to_csv('./temperature and precipitation/consolidated_df.csv')

# %%
frame=pd.read_csv('./temperature and precipitation/consolidated_df.csv')
frame.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        Date  tmax  tmin  prcp     filename  \
# 0           0             1  1871-01-01   NaN   NaN   0.0  USW00003822
# 1           1             2  1871-01-02   NaN   NaN   0.0  USW00003822
# 2           2             3  1871-01-03   NaN   NaN   0.0  USW00003822
# 3           3             4  1871-01-04   NaN   NaN   0.0  USW00003822
# 4           4             5  1871-01-05   NaN   NaN   0.0  USW00003822
#
#    Unnamed: 0.1.1
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
frame.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'], inplace=True)

# %%
frame.shape
# Out:
# (20798528, 5)

# %%
frame.isnull().sum()
# Out:
# Date              0
# tmax        1167008
# tmin        1165210
# prcp        1050446
# filename          0
# dtype: int64

# %%
frame.dtypes
# Out:
# Date         object
# tmax        float64
# tmin        float64
# prcp        float64
# filename     object
# dtype: object

# %%
imp = SimpleImputer(strategy='mean')
features=['tmax','tmin','prcp']
imp_frame=imp.fit_transform(frame[features])
imp_df=pd.DataFrame(imp_frame, columns = frame[features].columns)

# %%
imp_df.isnull().sum()
# Out:
# tmax    0
# tmin    0
# prcp    0
# dtype: int64

# %%
new_df=pd.concat([imp_df,frame[['Date','filename']]], axis=1)
new_df.head()
# Out:
#       tmax       tmin  prcp        Date     filename
# 0  65.7302  44.681459   0.0  1871-01-01  USW00003822
# 1  65.7302  44.681459   0.0  1871-01-02  USW00003822
# 2  65.7302  44.681459   0.0  1871-01-03  USW00003822
# 3  65.7302  44.681459   0.0  1871-01-04  USW00003822
# 4  65.7302  44.681459   0.0  1871-01-05  USW00003822

# %%
new_df.to_csv('./temperature and precipitation/cleaned_data.csv')

# %%
new_df['tmid']=(new_df['tmax']+new_df['tmin'])/2

# %%
new_df.head()
# Out:
#       tmax       tmin  prcp        Date     filename       tmid
# 0  65.7302  44.681459   0.0  1871-01-01  USW00003822  55.205829
# 1  65.7302  44.681459   0.0  1871-01-02  USW00003822  55.205829
# 2  65.7302  44.681459   0.0  1871-01-03  USW00003822  55.205829
# 3  65.7302  44.681459   0.0  1871-01-04  USW00003822  55.205829
# 4  65.7302  44.681459   0.0  1871-01-05  USW00003822  55.205829

# %%
# Out:
#                  tmax       tmin      prcp       tmid   if_prcp
# Date
# 1851-01-31  65.730200  44.681459  0.000968  55.205829  0.064516
# 1851-02-28  65.730200  44.681459  0.054286  55.205829  0.214286
# 1851-03-31  65.730200  44.681459  0.010968  55.205829  0.129032
# 1851-04-30  65.730200  44.681459  0.029000  55.205829  0.166667
# 1851-05-31  65.730200  44.681459  0.022903  55.205829  0.161290
# ...               ...        ...       ...        ...       ...
# 2020-08-31  87.787209  65.011420  0.104333  76.399314  0.281720
# 2020-09-30  79.515272  57.096080  0.098852  68.305676  0.251905
# 2020-10-31  68.089961  45.949511  0.091803  57.019736  0.277266
# 2020-11-30  60.932899  38.878309  0.082317  49.905604  0.260317
# 2020-12-31  49.435844  29.750783  0.079438  39.593314  0.306452
#
# [2040 rows x 5 columns]

# %%
new_df.head()
# Out:
#                tmax       tmin  prcp     filename       tmid  if_prcp
# Date
# 1871-01-01  65.7302  44.681459   0.0  USW00003822  55.205829        0
# 1871-01-02  65.7302  44.681459   0.0  USW00003822  55.205829        0
# 1871-01-03  65.7302  44.681459   0.0  USW00003822  55.205829        0
# 1871-01-04  65.7302  44.681459   0.0  USW00003822  55.205829        0
# 1871-01-05  65.7302  44.681459   0.0  USW00003822  55.205829        0

# %%
new_df['prcp'].value_counts()
# Out:
# 0.000000     13989250
# 0.094554      1050446
# 0.010000       567522
# 0.020000       414226
# 0.030000       291878
#                ...
# 22.750000           2
# 9.300000            2
# 9.020000            2
# 6.090000            2
# 15.290000           2
# Name: prcp, Length: 930, dtype: int64

# %%
new_df['if_prcp']=(new_df['prcp']>0).astype(int)
new_df.head()
# Out:
#       tmax       tmin  prcp        Date     filename       tmid  if_prcp
# 0  65.7302  44.681459   0.0  1871-01-01  USW00003822  55.205829        0
# 1  65.7302  44.681459   0.0  1871-01-02  USW00003822  55.205829        0
# 2  65.7302  44.681459   0.0  1871-01-03  USW00003822  55.205829        0
# 3  65.7302  44.681459   0.0  1871-01-04  USW00003822  55.205829        0
# 4  65.7302  44.681459   0.0  1871-01-05  USW00003822  55.205829        0

# %%
new_df['if_prcp'].value_counts()
# Out:
# 0    13989250
# 1     6809278
# Name: if_prcp, dtype: int64

# %%
new_df.shape
# Out:
# (20798528, 7)

# %%
new_df.head(1)
# Out:
#       tmax       tmin  prcp        Date     filename       tmid  if_prcp
# 0  65.7302  44.681459   0.0  1871-01-01  USW00003822  55.205829        0

# %%
plt.figure(figsize=(10,8))
sns.heatmap(new_df.corr()[['if_prcp']].sort_values(by='if_prcp', ascending=False),
            annot=True,
            vmin=-1,
            vmax=1,
            cmap='icefire');

# %%
new_df.set_index('Date', inplace = True)
new_df.index=pd.to_datetime(new_df.index)
new_df.resample('1M').mean()

# %%
new_df.to_csv('./temperature and precipitation/monthly.csv')

# %%
drought=pd.read_csv('./temperature and precipitation/drought1871.csv')

drought.head()
# Out:
#     MapDate                        Region      None        D0        D1  \
# 0  20211214                       Central      0.00      0.00      0.00
# 1  20211214                       Central  2,607.81  4,372.41      0.00
# 2  20211214  Cheyenne & Niobrara Drainage      0.00  1,848.56  4,515.72
# 3  20211214                  East Central    115.62  5,459.76      0.00
# 4  20211214              Extreme Southern      0.00      0.00      0.00
#
#          D2        D3         D4  ValidStart    ValidEnd  StatisticFormatID  \
# 0  1,057.49  7,663.36  13,493.12  2021-12-14  2021-12-20                  2
# 1      0.00      0.00       0.00  2021-12-14  2021-12-20                  2
# 2    981.97      0.00       0.00  2021-12-14  2021-12-20                  2
# 3      0.00      0.00       0.00  2021-12-14  2021-12-20                  2
# 4  2,841.68  5,553.79   1,586.81  2021-12-14  2021-12-20                  2
#
#    ClimateDivisionsID
# 0                2404
# 1                4604
# 2                4807
# 3                3206
# 4                2604

# %%
drought.tail()
# Out:
#          MapDate                  Region       None        D0        D1  \
# 409117  20000104           South Central       0.00  5,651.76    111.22
# 409118  20000104           South Central  16,840.81      0.00      0.00
# 409119  20000104               Southeast       0.00      0.00  5,415.06
# 409120  20000104               Southeast       0.00     11.11  5,643.18
# 409121  20000104  Southeast Desert Basin  36,001.11  9,632.78      0.00
#
#               D2    D3    D4  ValidStart    ValidEnd  StatisticFormatID  \
# 409117      0.00  0.00  0.00  2000-01-04  2000-01-10                  2
# 409118      0.00  0.00  0.00  2000-01-04  2000-01-10                  2
# 409119      0.00  0.00  0.00  2000-01-04  2000-01-10                  2
# 409120  1,055.44  0.00  0.00  2000-01-04  2000-01-10                  2
# 409121      0.00  0.00  0.00  2000-01-04  2000-01-10                  2
#
#         ClimateDivisionsID
# 409117                3908
# 409118                4204
# 409119                1309
# 409120                2509
# 409121                 407

# %%
drought.shape
# Out:
# (409122, 12)

# %%
drought.set_index('ValidStart', inplace=True)
drought.index = pd.to_datetime(drought.index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-ef791752d18c> in <module>
# ----> 1 drought.set_index('ValidStart', inplace=True)
#       2 drought.index = pd.to_datetime(drought.index)
#       3 drought.resample('1M').mean()
#
# /opt/anaconda3/envs/dsi-111/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['ValidStart'] are in the columns"

# %%
drought.head()
# Out:
#              MapDate                        Region      None        D0  \
# ValidStart
# 2021-12-14  20211214                       Central      0.00      0.00
# 2021-12-14  20211214                       Central  2,607.81  4,372.41
# 2021-12-14  20211214  Cheyenne & Niobrara Drainage      0.00  1,848.56
# 2021-12-14  20211214                  East Central    115.62  5,459.76
# 2021-12-14  20211214              Extreme Southern      0.00      0.00
#
#                   D1        D2        D3         D4    ValidEnd  \
# ValidStart
# 2021-12-14      0.00  1,057.49  7,663.36  13,493.12  2021-12-20
# 2021-12-14      0.00      0.00      0.00       0.00  2021-12-20
# 2021-12-14  4,515.72    981.97      0.00       0.00  2021-12-20
# 2021-12-14      0.00      0.00      0.00       0.00  2021-12-20
# 2021-12-14      0.00  2,841.68  5,553.79   1,586.81  2021-12-20
#
#             StatisticFormatID  ClimateDivisionsID
# ValidStart
# 2021-12-14                  2                2404
# 2021-12-14                  2                4604
# 2021-12-14                  2                4807
# 2021-12-14                  2                3206
# 2021-12-14                  2                2604

# %%
drought.resample('1M').mean()
# Out:
#                MapDate  StatisticFormatID  ClimateDivisionsID
# ValidStart
# 2000-01-31  20000114.5                2.0         2578.904762
# 2000-02-29  20000215.0                2.0         2578.904762
# 2000-03-31  20000317.5                2.0         2578.904762
# 2000-04-30  20000414.5                2.0         2578.904762
# 2000-05-31  20000516.0                2.0         2578.904762
# ...                ...                ...                 ...
# 2021-08-31  20210817.0                2.0         2578.904762
# 2021-09-30  20210917.5                2.0         2578.904762
# 2021-10-31  20211015.5                2.0         2578.904762
# 2021-11-30  20211116.0                2.0         2578.904762
# 2021-12-31  20211210.5                2.0         2578.904762
#
# [264 rows x 3 columns]

# %%
# Out:
#              MapDate                        Region       None        D0  \
# ValidStart
# 2021-12-14  20211214                       Central       0.00      0.00
# 2021-12-14  20211214                       Central   2,607.81  4,372.41
# 2021-12-14  20211214  Cheyenne & Niobrara Drainage       0.00  1,848.56
# 2021-12-14  20211214                  East Central     115.62  5,459.76
# 2021-12-14  20211214              Extreme Southern       0.00      0.00
# ...              ...                           ...        ...       ...
# 2000-01-04  20000104                 South Central       0.00  5,651.76
# 2000-01-04  20000104                 South Central  16,840.81      0.00
# 2000-01-04  20000104                     Southeast       0.00      0.00
# 2000-01-04  20000104                     Southeast       0.00     11.11
# 2000-01-04  20000104        Southeast Desert Basin  36,001.11  9,632.78
#
#                   D1        D2        D3         D4    ValidEnd  \
# ValidStart
# 2021-12-14      0.00  1,057.49  7,663.36  13,493.12  2021-12-20
# 2021-12-14      0.00      0.00      0.00       0.00  2021-12-20
# 2021-12-14  4,515.72    981.97      0.00       0.00  2021-12-20
# 2021-12-14      0.00      0.00      0.00       0.00  2021-12-20
# 2021-12-14      0.00  2,841.68  5,553.79   1,586.81  2021-12-20
# ...              ...       ...       ...        ...         ...
# 2000-01-04    111.22      0.00      0.00       0.00  2000-01-10
# 2000-01-04      0.00      0.00      0.00       0.00  2000-01-10
# 2000-01-04  5,415.06      0.00      0.00       0.00  2000-01-10
# 2000-01-04  5,643.18  1,055.44      0.00       0.00  2000-01-10
# 2000-01-04      0.00      0.00      0.00       0.00  2000-01-10
#
#             StatisticFormatID  ClimateDivisionsID
# ValidStart
# 2021-12-14                  2                2404
# 2021-12-14                  2                4604
# 2021-12-14                  2                4807
# 2021-12-14                  2                3206
# 2021-12-14                  2                2604
# ...                       ...                 ...
# 2000-01-04                  2                3908
# 2000-01-04                  2                4204
# 2000-01-04                  2                1309
# 2000-01-04                  2                2509
# 2000-01-04                  2                 407
#
# [409122 rows x 11 columns]

# %%
clean=pd.read_csv('./temperature and precipitation/cleaned_data.csv')
clean.head()
# Out:
#    Unnamed: 0     tmax       tmin  prcp        Date     filename
# 0           0  65.7302  44.681459   0.0  1871-01-01  USW00003822
# 1           1  65.7302  44.681459   0.0  1871-01-02  USW00003822
# 2           2  65.7302  44.681459   0.0  1871-01-03  USW00003822
# 3           3  65.7302  44.681459   0.0  1871-01-04  USW00003822
# 4           4  65.7302  44.681459   0.0  1871-01-05  USW00003822
